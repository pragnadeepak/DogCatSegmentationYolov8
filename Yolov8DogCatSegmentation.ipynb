# %% [markdown]
# <a href="https://colab.research.google.com/github/pragnadeepak/DogCatSegmentationYolov8/blob/main/Yolov8DogCatSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Sep  7 09:35:02 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation"

# %%
# %cd "/content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation"
# Out:
# /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=data.yaml epochs=100 imgsz=640 save=True
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=val model=runs/segment/train5/weights/best.pt data=data.yaml
# Out:
# 2023-09-07 10:15:55.100389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-07 10:15:56.030704: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/dogCatDataset/valid/labels.cache... 16 images, 0 backgrounds, 0 corrupt: 100% 16/16 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.02it/s]
# ...

# %%
# !yolo task=segment mode=predict model=runs/segment/train5/weights/best.pt conf=0.25 source=dogCatDataset/test/images save=true
# Out:
# 2023-09-07 10:17:09.306585: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-07 10:17:10.525414: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/8 /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/dogCatDataset/test/images/10_jpg.rf.4b48fdea50715d1db92eef24e213ee81.jpg: 640x640 1 cat, 21.0ms
# image 2/8 /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/dogCatDataset/test/images/16_jpg.rf.c0a2725c096aebb35216a17f136bf254.jpg: 640x640 1 cat, 21.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'runs/segment/predict/*.jpg'):
      display(Image(filename=image_path, height=300))
      print("\n")

# %%
# !yolo task=segment mode=predict model=runs/segment/train5/weights/best.pt conf=0.25 source="https://storage.googleapis.com/petbacker/images/blog/2017/dog-and-cat-cover.jpg" save=true
# Out:
# 2023-09-07 10:19:47.060437: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-07 10:19:47.947338: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
#
# ...
# 100% 70.8k/70.8k [00:00<00:00, 237kB/s]
# image 1/1 /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/dog-and-cat-cover.jpg: 352x640 1 cat, 1 dog, 147.6ms
# Speed: 0.6ms pre-process, 147.6ms inference, 127.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict2

# %%
display(Image(filename="/content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/runs/segment/predict2/dog-and-cat-cover.jpg", height=300))

# %%
# !yolo task=segment mode=predict model=runs/segment/train5/weights/best.pt conf=0.25 source="https://www.collinsdictionary.com/images/full/hen_151155842.jpg" save=true
# Out:
# 2023-09-07 10:24:53.256000: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-07 10:24:54.617873: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
#
# ...
# 100% 577k/577k [00:00<00:00, 1.73MB/s]
# image 1/1 /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/hen_151155842.jpg: 640x544 1 cat, 84.1ms
# Speed: 0.7ms pre-process, 84.1ms inference, 97.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict3

# %%
display(Image(filename="/content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/runs/segment/predict3/hen_151155842.jpg", height=300))

# %%
# !yolo task=segment mode=predict model=runs/segment/train5/weights/best.pt conf=0.25 source="/content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/deepak.JPG" save=true
# Out:
# 2023-09-07 10:28:33.465436: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-07 10:28:34.347989: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/deepak.JPG: 640x480 1 dog, 146.3ms
# Speed: 0.9ms pre-process, 146.3ms inference, 173.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict4

# %%
display(Image(filename="/content/drive/MyDrive/Wavelabs/YoloV8Segmentation/DogCatSegmentation/runs/segment/predict4/deepak.JPG", height=300))
